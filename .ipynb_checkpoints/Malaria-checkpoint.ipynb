# %%
import numpy as np
import pandas as pd
import h5py
import keras 
from keras.models import *
import keras.layers as layers
from keras.optimizers import *
import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow.python.ops import nn

# %%
def loss_function_generator(y_pred, y_true):

    total_gen_loss = tf.reduce_mean(tf.abs(y_true - y_pred))
    
    return total_gen_loss

# %%
LR = 0.001
input_shape = (142,163,3)
inputs = keras.Input(shape=input_shape)

outputs = tf.keras.applications.VGG19(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=input_shape,
    pooling=max,
    classes=2,
    classifier_activation="softmax",
)
# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

model = Model(inputs = inputs, outputs = outputs)

model.compile(optimizer = Adam(learning_rate = LR), loss = 'binary_crossentropy', metrics = ['accuracy'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 142, 163, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 142, 163, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 71, 82, 32)   896         rescaling[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 71, 82, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 71, 82, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 71, 82, 64)   18496       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 71, 82, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 71, 82, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 71, 82, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 71, 82, 128)  8896        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 71, 82, 128)  512         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 71, 82, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 71, 82, 128)  17664       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 71, 82, 128)  512         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 36, 41, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 36, 41, 128)  8320        activation_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 36, 41, 128)  0           max_pooling2d[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 36, 41, 1024) 133248      add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 36, 41, 1024) 4096        separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 36, 41, 1024) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 18, 21, 1024) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 387072)       0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 387072)       0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            387073      dropout[0][0]
# ==================================================================================================
# Total params: 580,097
# Trainable params: 577,345
# Non-trainable params: 2,752
# __________________________________________________________________________________________________

# %%
image_size = (142,163)
batch_size = 256
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    "archive/train",
    labels = "inferred",
    label_mode = "binary",
    validation_split = 0.8,
    subset = "training",
    image_size = image_size,
    batch_size = batch_size,
    shuffle = True,
    seed = 1
    )

val_data = tf.keras.preprocessing.image_dataset_from_directory(
    "archive/val",
    labels = "inferred",
    label_mode = "binary",
    validation_split = 0.1,
    subset = "validation",
    image_size = image_size,
    batch_size = batch_size,
    shuffle = True,
    seed = 2
    )
# Out:
# Found 20668 files belonging to 2 classes.
# Using 4134 files for training.
# Found 6890 files belonging to 2 classes.
# Using 689 files for validation.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in val_data.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
#train_data = train_data.prefetch(buffer_size=128)
#val_data = val_data.prefetch(buffer_size=128)

# %%
callbacks = [
]
history = model.fit(
                    train_data,
                    epochs=5, batch_size=batch_size, callbacks=callbacks,
                    validation_data=val_data
                    )
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-97fa5e1613ea> in <module>
#       1 callbacks = [
#       2 ]
# ----> 3 history = model.fit(
#       4                     train_data,
#       5                     epochs=5, batch_size=batch_size, callbacks=callbacks,
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1156                 _r=1):
#    1157               callbacks.on_train_batch_begin(step)
# -> 1158               tmp_logs = self.train_function(iterator)
#    1159               if data_handler.should_sync:
#    1160                 context.async_wait()
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     761     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     762     self._concrete_stateful_fn = (
# --> 763         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     764             *args, **kwds))
#     765
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3048       args, kwargs = None, None
#    3049     with self._lock:
# -> 3050       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3051     return graph_function
#    3052
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3442
#    3443           self._function_cache.missed.add(call_context_key)
# -> 3444           graph_function = self._create_graph_function(args, kwargs)
#    3445           self._function_cache.primary[cache_key] = graph_function
#    3446
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3277     arg_names = base_arg_names + missing_arg_names
#    3278     graph_function = ConcreteFunction(
# -> 3279         func_graph_module.func_graph_from_py_func(
#    3280             self._name,
#    3281             self._python_function,
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997         _, original_func = tf_decorator.unwrap(python_func)
#     998
# --> 999       func_outputs = python_func(*func_args, **func_kwargs)
#    1000
#    1001       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     973           # TODO(mdan): Push this block higher in tf.function's call stack.
#     974           try:
# --> 975             return autograph.converted_call(
#     976                 original_func,
#     977                 args,
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     444         result = converted_f(*effective_args, **kwargs)
#     445       else:
# --> 446         result = converted_f(*effective_args)
#     447     except Exception as e:
#     448       _attach_error_metadata(e, converted_f)
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training.py in tf__step_function(model, iterator)
#      29                 outputs = ag__.converted_call(ag__.ld(model).distribute_strategy.run, (ag__.ld(run_step),), dict(args=(ag__.ld(data),)), fscope)
#      30                 outputs = ag__.converted_call(ag__.ld(reduce_per_replica), (ag__.ld(outputs), ag__.ld(self).distribute_strategy), dict(reduction='first'), fscope)
# ---> 31                 ag__.converted_call(ag__.ld(write_scalar_summaries), (ag__.ld(outputs),), dict(step=ag__.ld(model)._train_counter), fscope)
#      32                 try:
#      33                     do_return = True
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training.py in tf__write_scalar_summaries(logs, step)
#      30                 name = ag__.Undefined('name')
#      31                 value = ag__.Undefined('value')
# ---> 32                 ag__.for_stmt(ag__.converted_call(ag__.ld(logs).items, (), None, fscope), None, loop_body, get_state_1, set_state_1, (), {'iterate_names': '(name, value)'})
#      33         return tf__write_scalar_summaries
#      34     return inner_factory
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py in for_stmt(iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#     441
#     442   else:
# --> 443     _py_for_stmt(iter_, extra_test, body, None, None)
#     444
#     445
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py in _py_for_stmt(***failed resolving arguments***)
#     470   else:
#     471     for target in iter_:
# --> 472       body(target)
#     473
#     474
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py in protected_body(protected_iter)
#     456     original_body = body
#     457     def protected_body(protected_iter):
# --> 458       original_body(protected_iter)
#     459       after_iteration()
#     460       before_iteration()
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training.py in loop_body(itr)
#      27                     def else_body():
#      28                         pass
# ---> 29                     ag__.if_stmt(ag__.converted_call(ag__.ld(_is_scalar), (ag__.ld(value),), None, fscope), if_body, else_body, get_state, set_state, (), 0)
#      30                 name = ag__.Undefined('name')
#      31                 value = ag__.Undefined('value')
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1170     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1171   else:
# -> 1172     _py_if_stmt(cond, body, orelse)
#    1173
#    1174
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py in _py_if_stmt(cond, body, orelse)
#    1223 def _py_if_stmt(cond, body, orelse):
#    1224   """Overload of if_stmt that executes a Python if statement."""
# -> 1225   return body() if cond else orelse()
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training.py in if_body()
#      23
#      24                     def if_body():
# ---> 25                         ag__.converted_call(ag__.ld(tf).summary.scalar, ('batch_' + ag__.ld(name), ag__.ld(value)), dict(step=ag__.ld(step)), fscope)
#      26
#      27                     def else_body():
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorboard\plugins\scalar\summary_v2.py in tf__scalar(name, data, step, description)
#      56                 do_return = False
#      57                 retval_ = ag__.UndefinedReturnValue()
# ---> 58                 summary_metadata = ag__.converted_call(ag__.ld(metadata).create_summary_metadata, (), dict(display_name=None, description=ag__.ld(description)), fscope)
#      59                 summary_scope = ag__.or_(lambda : ag__.converted_call(ag__.ld(getattr), (ag__.ld(tf).summary.experimental, 'summary_scope', None), None, fscope), lambda : ag__.ld(tf).summary.summary_scope)
#      60                 with ag__.ld(summary_scope)(ag__.ld(name), 'scalar_summary', values=[ag__.ld(data), ag__.ld(step)]) as (tag, _):
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorboard\plugins\scalar\metadata.py in tf__create_summary_metadata(display_name, description)
#      14                 retval_ = ag__.UndefinedReturnValue()
#      15                 content = ag__.converted_call(ag__.ld(plugin_data_pb2).ScalarPluginData, (), dict(version=ag__.ld(PROTO_VERSION)), fscope)
# ---> 16                 metadata = ag__.converted_call(ag__.ld(summary_pb2).SummaryMetadata, (), dict(display_name=ag__.ld(display_name), summary_description=ag__.ld(description), plugin_data=ag__.converted_call(ag__.ld(summary_pb2).SummaryMetadata.PluginData, (), dict(plugin_name=ag__.ld(PLUGIN_NAME), content=ag__.converted_call(ag__.ld(content).SerializeToString, (), None, fscope)), fscope)), fscope)
#      17                 try:
#      18                     do_return = True
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     444         result = converted_f(*effective_args, **kwargs)
#     445       else:
# --> 446         result = converted_f(*effective_args)
#     447     except Exception as e:
#     448       _attach_error_metadata(e, converted_f)
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\google\protobuf\internal\python_message.py in tf__SerializeToString(self, **kwargs)
#      23                 try:
#      24                     do_return = True
# ---> 25                     retval_ = ag__.converted_call(ag__.ld(self).SerializePartialToString, (), dict(**ag__.ld(kwargs)), fscope)
#      26                 except:
#      27                     do_return = False
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\google\protobuf\internal\python_message.py in tf__SerializePartialToString(self, **kwargs)
#       9                 retval_ = ag__.UndefinedReturnValue()
#      10                 out = ag__.converted_call(ag__.ld(BytesIO), (), None, fscope)
# ---> 11                 ag__.converted_call(ag__.ld(self)._InternalSerialize, (ag__.ld(out).write,), dict(**ag__.ld(kwargs)), fscope)
#      12                 try:
#      13                     do_return = True
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\google\protobuf\internal\python_message.py in tf__InternalSerialize(self, write_bytes, deterministic)
#      21                     nonlocal deterministic
#      22                     deterministic = ag__.converted_call(ag__.ld(bool), (ag__.ld(deterministic),), None, fscope)
# ---> 23                 ag__.if_stmt(ag__.ld(deterministic) is None, if_body, else_body, get_state, set_state, ('deterministic',), 1)
#      24                 descriptor = ag__.ld(self).DESCRIPTOR
#      25
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1170     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1171   else:
# -> 1172     _py_if_stmt(cond, body, orelse)
#    1173
#    1174
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py in _py_if_stmt(cond, body, orelse)
#    1223 def _py_if_stmt(cond, body, orelse):
#    1224   """Overload of if_stmt that executes a Python if statement."""
# -> 1225   return body() if cond else orelse()
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\google\protobuf\internal\python_message.py in if_body()
#      16                 def if_body():
#      17                     nonlocal deterministic
# ---> 18                     deterministic = ag__.converted_call(ag__.ld(api_implementation).IsPythonDefaultSerializationDeterministic, (), None, fscope)
#      19
#      20                 def else_body():
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     439     return _fall_back_unconverted(f, args, kwargs, options, e)
#     440
# --> 441   with StackTraceMapper(converted_f), tf_stack.CurrentModuleFilter():
#     442     try:
#     443       if kwargs is not None:
#
# c:\users\91942\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\util\tf_stack.py in __init__(self)
#     136         outer_f = f.f_back
#     137         if outer_f is not None:
# --> 138           filter_filename = inspect.getsourcefile(outer_f)
#     139       self._filename = filter_filename
#     140       # This may be called repeatedly: once on entry by the superclass, then by
#
# c:\users\91942\appdata\local\programs\python\python39\lib\inspect.py in getsourcefile(object)
#     704                  importlib.machinery.EXTENSION_SUFFIXES):
#     705         return None
# --> 706     if os.path.exists(filename):
#     707         return filename
#     708     # only return a non-existent filename if the module has a PEP 302 loader
#
# c:\users\91942\appdata\local\programs\python\python39\lib\genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except (OSError, ValueError):
#      21         return False
#
# KeyboardInterrupt:
